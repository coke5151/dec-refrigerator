# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
from pydantic import BaseModel

# %% [markdown]
# # Pydantic

# %%
class Account(BaseModel):
    name: str
    address: str
    group_id: str
    balance: float

# %%
class AccountJoin(BaseModel):
    name: str
    address: str
    group_id: str

# %%
class FoodInsert(BaseModel):
    name: str
    insert_time: str
    due_date: str | None = None
    money_cost: float
    buyer_address: str
    group_id: str
    notes: str | None = None

# %%
class Food(BaseModel):
    name: str
    insert_time: str
    due_date: str | None = None
    money_cost: float
    buyer_address: str
    quantity_left_percentage: float
    food_address: str
    simpler_food_address: str
    group_id: str
    notes: str | None = None

# %%
class FoodPie(BaseModel):
    name: str
    rate: float

# %%
class FoodUsageRecord(BaseModel):
    use_time: str
    use_food_group_id: str
    use_food_address: str
    use_food_amount_percentage: float
    user_address: str
    notes: str

# %%
class TransferRequest(BaseModel):
    transfer_time: str
    from_address: str
    to_address: str
    amount: float
    group_id: str
    notes: str | None = None

# %%
class TransferRecord(BaseModel):
    transfer_time: str
    from_address: str
    from_name: str
    to_address: str
    to_name: str
    amount: float
    group_id: str
    notes: str | None = None

# %% [markdown]
# # Database

# %%
import random
def random_address():
    hex_chars = '0123456789abcdef'
    random_hex = ''.join(random.choice(hex_chars) for _ in range(40))
    return f"0x{random_hex}"

# %%
class Database:
    def __init__(self):
        self.foods: dict[str, list[Food]] = dict()
        self.groups: dict[str, list[Account]] = dict()
        self.transactions: dict[str, list[TransferRecord]] = dict()
        
    def insert_food(self, fi: FoodInsert):
        address = random_address()
        f = Food(
            name = fi.name,
            insert_time = fi.insert_time,
            due_date = fi.due_date,
            money_cost = fi.money_cost,
            buyer_address = fi.buyer_address,
            quantity_left_percentage = 100,
            food_address = address,
            simpler_food_address = address[:4],
            group_id = fi.group_id,
            notes = fi.notes
        )
        if fi.group_id not in self.foods:
            self.foods[fi.group_id] = list()
        self.foods[fi.group_id].append(f)
        return {
            "message": "成功新增食物"
        }

    def single_food(self, address: str, group_id: str):
        
        the_food_group = list()

        if group_id in self.foods:
            the_food_group = self.foods[group_id]
            
        for f in the_food_group:
            if f.food_address == address:
                return f
        return None

# class Food(BaseModel):
#     name: str
#     insert_time: str
#     due_date: str | None = None
#     money_cost: float
#     buyer_address: str
#     quantity_left_percentage: float
#     food_address: str
#     simpler_food_address: str
#     group_id: str
#     notes: str | None = None
    
    def all_foods(self, group_id):
        if group_id not in self.foods:
            empty_list = list()
            empty_list.append(
                Food(
                    name="目前尚無庫存",
                    insert_time="入庫日期",
                    due_date="保存期限",
                    money_cost=0,
                    buyer_address="",
                    quantity_left_percentage=0.0,
                    food_address="食材地址",
                    simpler_food_address="",
                    group_id=group_id,
                    notes=""
                ),
            )
            return empty_list
        return self.foods[group_id]
    
    def food_pies(self, group_id):
        all_food = self.all_foods(group_id)
        food_pies = list()
        sum_value = 0
        for food in all_food:
            value = food.money_cost * food.quantity_left_percentage / 100
            sum_value += value
        for food in all_food:
            if sum_value == 0:
                food_pies.append(
                    FoodPie(
                        name=food.name,
                        rate=1
                    ),
                )
                break
            else:
                food_pies.append(
                    FoodPie(
                        name=food.name,
                        rate=(food.money_cost * food.quantity_left_percentage / 100) / sum_value
                    ),
                )
        return food_pies
    
    def use_food(self, record: FoodUsageRecord):
        food = self.single_food(address=record.use_food_address, group_id=record.use_food_group_id)
        if food is None:
            return {
                "message": "食材不存在"
            }
        price = food.money_cost
        if record.use_food_group_id not in self.groups:
            return {
                "message": "食材不存在目前的 group"
            }
        for i in range(len(self.groups[record.use_food_group_id])):
            if self.groups[record.use_food_group_id][i].address == record.user_address:
                self.groups[record.use_food_group_id][i].balance -= (record.use_food_amount_percentage / 100 * price)
                for j in range(len(self.foods[record.use_food_group_id])):
                    if self.foods[record.use_food_group_id][j].food_address == record.use_food_address:
                        self.foods[record.use_food_group_id][j].quantity_left_percentage -= record.use_food_amount_percentage
                        break
                break
        return {
            "message": "成功使用食材"
        }
        
    def single_account(self, address: str, group_id: str):
        if group_id not in self.groups:
            return None
        for ac in self.groups[group_id]:
            if ac.address == address:
                return ac
        return None

    def all_accounts(self, group_id):
        if group_id not in self.groups:
            return None
        return self.groups[group_id]
    
    def account_join_group(self, aj: AccountJoin):
        already_in = False

        if aj.group_id not in self.groups:
            self.groups[aj.group_id] = list()

        for i in range(len(self.groups[aj.group_id])):
            if self.groups[aj.group_id][i].address == aj.address:
                already_in = True
                self.groups[aj.group_id][i].name = aj.name
                break
        # for ac in self.groups[aj.group_id]:
        #     if ac.address == aj.address:
        #         already_in = True
        #         break

        if not already_in:
            self.groups[aj.group_id].append(
                Account(
                    name=aj.name,
                    address=aj.address,
                    group_id=aj.group_id,
                    balance=0
                )
            )
            return {
                "message": "成功新增至群組"
            }
        else:
            return {
                "message": "已在群組中，名稱已修改"
            }

# class TransferRecord(BaseModel):
#     transfer_time: str
#     from_address: str
#     from_name: str
#     to_address: str
#     to_name: str
#     amount: float
#     group_id: str
#     notes: str | None = None
        
    def all_transactions(self, group_id: str):
        if group_id not in self.transactions:
            empty_list = list()
            empty_list.append(
                TransferRecord(
                    transfer_time="",
                    from_address="",
                    from_name="還款者",
                    to_address="",
                    to_name="收款者",
                    amount=0,
                    group_id=group_id,
                    notes=""
                ),
            )
            return empty_list
        return self.transactions[group_id]
    
    def transfer(self, record: TransferRequest):
        success_from = False
        success_to = False
        
        if record.group_id not in self.groups:
            return False

        from_name = ""
        to_name = ""
        for i in range(len(self.groups[record.group_id])):
            if self.groups[record.group_id][i].address == record.from_address:
                self.groups[record.group_id][i].balance += record.amount
                from_name = self.groups[record.group_id][i].name
                success_from = True
            elif self.groups[record.group_id][i].address == record.to_address: 
                self.groups[record.group_id][i].balance -= record.amount
                to_name = self.groups[record.group_id][i].name
                success_to = True
            if success_from and success_to:
                if record.group_id not in self.transactions:
                    self.transactions[record.group_id] = list()
                self.transactions[record.group_id].append(
                    TransferRecord(
                        transfer_time=record.transfer_time,
                        from_address=record.from_address,
                        from_name=from_name,
                        to_address=record.to_address,
                        to_name=to_name,
                        amount=record.amount,
                        group_id=record.group_id,
                        notes=record.notes
                    ),
                )
                break
        return success_from and success_to

# %%
db = Database()

# %% [markdown]
# # FastAPI

# %%
from fastapi import FastAPI
from fastapi.middleware.cors import CORSMiddleware

# %%
app = FastAPI()
app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

# %%
@app.get("/")
async def read_root():
    return {"message": "查看 /docs 以獲得詳盡的 API Document"}

# %%
@app.get("/helloworld")
async def hello_world():
    """回傳 \"Hello, World!\""""
    return {
        "message": "Hello, World!"
    }

# %%
@app.get("/account/single")
async def single_account(address: str, group_id):
    """取得指定 account 的資料"""
    return {
        "message": f"地址為 {address} 的帳戶的資料",
        "data": db.single_account(address=address, group_id=group_id)
    }

# %%
@app.get("/account/all/")
async def all_account_data(group_id: str):
    """回傳指定 group 中所有 account 的資料"""
    return {
        "message": f"group_id: {group_id} 的所有 account 的資料",
        "data": db.all_accounts(group_id=group_id)
    }

# %%
@app.get("/account/transfer/")
async def all_transfer_records_in_group(group_id: str):
    """回傳指定 group 中所有的交易記錄"""
    return {
        "message": f"group_id: {group_id} 的所有交易記錄",
        "data": db.all_transactions(group_id=group_id)
    }

# %%
@app.post("/account/transfer/")
async def account_transfer(record: TransferRequest):
    if db.transfer(record):
        return {
            "message": "轉帳成功"
        }
    else:
        return {
            "message": "轉帳失敗"
        }

# %%
@app.post("/account/join_group/")
async def join_group(aj: AccountJoin):
    print()
    print()
    print(aj)
    print()
    print()    
    """將帳戶加入群組"""
    return db.account_join_group(aj=aj)

# %%
@app.get("/food/single/")
async def single_food_data(address: str, group_id: str):
    """取得指定 address 食物的資料"""
    return db.single_food(address=address, group_id=group_id)

# %%
@app.get("/food/all/")
async def get_all_food(group_id: str):
    """取得指定 group 中所有的食物資料"""
    return db.all_foods(group_id=group_id)

# %%
@app.get("/food/pie/")
async def get_food_pie(group_id: str):
    """取得指定 group 中所有的食物的百分比"""
    return db.food_pies(group_id=group_id)

# %%
@app.post("/food/insert/")
async def insert_food(fi: FoodInsert):
    """新增食物"""
    return db.insert_food(fi)

# %%
@app.post("/food/use/")
async def use_food(record: FoodUsageRecord):
    """使用指定的食物"""
    return db.use_food(record=record)

# %%
import uvicorn
config = uvicorn.Config(app, host="0.0.0.0", port=25565)
server = uvicorn.Server(config)
await server.serve()
# Out:
# INFO:     Started server process [18000]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:25565 (Press CTRL+C to quit)
# INFO:     101.136.169.244:2241 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     101.136.169.244:2322 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     101.136.169.244:2324 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     101.136.169.244:2341 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     101.136.169.244:2342 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     101.136.169.244:2324 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     101.136.169.244:2982 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     101.136.169.244:2983 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     101.136.169.244:2972 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     101.136.169.244:2972 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     101.136.169.244:2192 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     101.136.169.244:2197 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     101.136.169.244:2201 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     101.136.169.244:2192 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     101.136.169.244:2657 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     101.136.169.244:2660 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     101.136.169.244:2663 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     101.136.169.244:2657 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     101.136.169.244:2081 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     101.136.169.244:2080 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     101.136.169.244:2091 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     101.136.169.244:2080 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44656 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:44658 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44660 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44656 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44662 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44664 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44666 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:44666 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44668 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44670 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44672 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:44672 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
#
#
# name='王珈源' address='0x2766896449cad4afae653d7fd27201f526d5d4e8' group_id='123'
#
#
# INFO:     192.168.1.1:44674 - "POST /account/join_group/ HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44680 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44676 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:44678 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44676 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44682 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44684 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44686 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44688 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:44690 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44688 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44736 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:44738 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44740 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44736 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44748 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44750 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:44752 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44750 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44754 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:44756 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44754 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:44758 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
#
#
# name='鄭弘翊' address='0xe6df531e6bd13925b67f04de87f0af94ecbfefb4' group_id='123'
#
#
# INFO:     192.168.1.1:45972 - "POST /account/join_group/ HTTP/1.1" 200 OK
# INFO:     192.168.1.1:45974 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:45976 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:45978 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:45982 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:45980 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:45980 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:45984 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:45986 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:45988 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:45984 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:45990 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:45992 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:45994 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:45990 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:45996 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:45998 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46004 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46006 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46056 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46058 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46120 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46122 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46124 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46126 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46132 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46134 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46136 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46142 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46144 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46146 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46150 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46152 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46154 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46156 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46148 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46158 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46160 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46162 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46164 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46166 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46168 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46172 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46176 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46178 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46180 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46182 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46186 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46184 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46188 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46190 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46192 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46194 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46196 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46198 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46202 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46200 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46204 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46206 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46208 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46210 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46212 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46214 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46218 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46216 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46220 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46216 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46222 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46224 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46226 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46228 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46232 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46230 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46234 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46236 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46238 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46240 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46242 - "POST /food/insert/ HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46244 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46248 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46246 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46250 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46252 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46254 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46256 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46258 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46260 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46262 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46264 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46266 - "POST /food/insert/ HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46268 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46272 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46270 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46276 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46274 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46278 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46280 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46282 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46284 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46286 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46288 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46292 - "POST /food/insert/ HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46294 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46298 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46296 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46302 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46304 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46300 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46306 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46308 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46310 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46312 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46314 - "GET /food/single/?address=0xdc8db35a6e62da339980cfc770014bc570021d32&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46316 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46318 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46320 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46322 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46324 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46326 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46322 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46328 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46332 - "POST /food/use/ HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46334 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46338 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46336 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46338 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46342 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46340 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46346 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46344 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46348 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46352 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46354 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46356 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46360 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46362 - "GET /food/single/?address=0x8884d8fe7d1b0443383744804b4214411ac57f2f&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46364 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46366 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46370 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46376 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46380 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46374 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46378 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46372 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46372 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46382 - "POST /food/use/ HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46386 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46384 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46388 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46384 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46394 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46390 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46390 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46392 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46398 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46396 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46400 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46400 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46404 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46406 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46402 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46402 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46408 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46410 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46412 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46412 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
#
#
# name='鄭弘翊' address='0xe6df531e6bd13925b67f04de87f0af94ecbfefb4' group_id='123'
#
#
# INFO:     192.168.1.1:46414 - "POST /account/join_group/ HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46416 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46418 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46420 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46416 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46422 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46426 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46424 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46422 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46428 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46430 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46432 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46432 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46434 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46438 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46436 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46434 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46444 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46440 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46442 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46442 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46446 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46448 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46450 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46452 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46454 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46452 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46456 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46458 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46460 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46462 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46462 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46464 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46466 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46468 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46470 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46464 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46472 - "POST /account/transfer/ HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46476 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46474 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46478 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46474 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46480 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46482 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46484 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46480 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46488 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46490 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46486 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46486 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46494 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46492 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46496 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46492 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46498 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46500 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46502 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46500 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46504 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46506 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46508 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46508 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46514 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46510 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46512 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46510 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46516 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46518 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46520 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46520 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46522 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46526 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46524 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46522 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46528 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46532 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46528 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46534 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46536 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46538 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46534 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46530 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46544 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46540 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46546 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46548 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46550 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46546 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46542 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46542 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46556 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46552 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46554 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46552 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46558 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46560 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46562 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46560 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46566 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46564 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46568 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46564 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:45218 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:45232 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46570 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46572 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46574 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46576 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46570 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46578 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46580 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46582 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46584 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46580 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:33730 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:33734 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:33740 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:33746 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40628 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40634 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40638 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:40654 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40662 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40670 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40680 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40694 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40700 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40706 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40718 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40732 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44286 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44292 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44308 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44330 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44314 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44332 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44346 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44362 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44372 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:39616 - "GET /food/single/?address=0xdc8db35a6e62da339980cfc770014bc570021d32&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:39630 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:39640 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:39646 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:39658 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:41720 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:41730 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:41740 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:41742 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:41754 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:41748 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:41756 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:41764 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
#
#
# name='王曉明' address='0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7' group_id='123'
#
#
# INFO:     54.160.134.154:41776 - "POST /account/join_group/ HTTP/1.1" 200 OK
# INFO:     54.160.134.154:42882 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:42888 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:42896 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:42902 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:34246 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:34252 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:34254 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:34262 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:34270 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:39020 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:39022 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:39032 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:39042 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:39052 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:39068 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:39074 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:39076 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:39086 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:39088 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:39090 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:39102 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:42342 - "GET /food/single/?address=0xdc8db35a6e62da339980cfc770014bc570021d32&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:42354 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:42366 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:42370 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:42384 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:42400 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:42412 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:42418 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:42422 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46658 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46664 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46662 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46660 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46668 - "GET /account/single/?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     192.168.1.1:46666 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46670 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46664 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46668 - "GET /account/single?address=0xe6df531e6bd13925b67f04de87f0af94ecbfefb4&group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46674 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46676 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46680 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46678 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46682 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     192.168.1.1:46684 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:36088 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:36094 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:36108 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:36122 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:36134 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:36144 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:36166 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:36146 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:36156 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:36182 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:36198 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:36202 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:57468 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:57472 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:43116 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:43124 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:43130 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:43132 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:43164 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:43154 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:43142 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:43178 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40272 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40284 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40302 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:40292 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40308 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40314 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40324 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40354 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40340 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:40356 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40378 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:40360 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:40374 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:51408 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:51442 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:51420 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:51428 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:51450 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:51446 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:51460 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:51470 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:51474 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:51480 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:42224 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:42226 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:42236 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:42258 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:42252 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:42274 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:42272 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:42284 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:43528 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:43538 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:43548 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:43552 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:43554 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:43570 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:43598 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:43590 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:43578 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:43612 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:43628 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:57992 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:58006 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:58010 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:58012 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44138 - "GET /account/single/?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:44154 - "GET /account/single?address=0x2766896449cad4afae653d7fd27201f526d5d4e8&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44170 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44156 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44184 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:44196 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44212 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44240 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44226 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:44252 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44260 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44264 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:44266 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:41516 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:58222 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:58236 - "GET /account/transfer/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:58234 - "GET /account/single/?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 307 Temporary Redirect
# INFO:     54.160.134.154:58238 - "GET /account/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:58244 - "GET /account/single?address=0x750cBC68a76642a0877665BEC0Db3B93eC193Fb7&group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:58256 - "GET /food/all/?group_id=123 HTTP/1.1" 200 OK
# INFO:     54.160.134.154:58254 - "GET /food/pie/?group_id=123 HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [18000]
